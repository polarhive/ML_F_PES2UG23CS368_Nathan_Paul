# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge

import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostRegressor
import optuna

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

print("Train shape:", train.shape)
print("Test shape:", test.shape)
train.head()
# Out:
# Train shape: (517754, 14)
# Test shape: (172585, 13)
#    id road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0   0     urban          2       0.06           35  daylight   rainy
# 1   1     urban          4       0.99           35  daylight   clear
# 2   2     rural          4       0.63           70       dim   clear
# 3   3   highway          4       0.07           35       dim   rainy
# 4   4     rural          1       0.58           60  daylight   foggy
#
#    road_signs_present  public_road time_of_day  holiday  school_season  \
# 0               False         True   afternoon    False           True
# 1                True        False     evening     True           True
# 2               False         True     morning     True          False
# 3                True         True     morning    False          False
# 4               False        False     evening     True          False
#
#    num_reported_accidents  accident_risk
# 0                       1           0.13
# 1                       0           0.35
# 2                       2           0.30
# 3                       1           0.21
# 4                       1           0.56

# %%
train['source'] = 'train'
test['source'] = 'test'
test['accident_risk'] = np.nan

data = pd.concat([train, test], ignore_index=True)
print("Combined shape:", data.shape)
# Out:
# Combined shape: (690339, 15)

# %%
cat_cols = ['road_type', 'lighting', 'weather', 'time_of_day']
bool_cols = ['road_signs_present', 'public_road', 'holiday', 'school_season']

for col in cat_cols + bool_cols:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col].astype(str))

# %%
print("Available columns:", data.columns.tolist())
# Out:
# Available columns: ['id', 'road_type', 'num_lanes', 'curvature', 'speed_limit', 'lighting', 'weather', 'road_signs_present', 'public_road', 'time_of_day', 'holiday', 'school_season', 'num_reported_accidents', 'accident_risk', 'source']

# %%
# Basic features
data['lanes_per_speed'] = data['num_lanes'] / data['speed_limit']
data['curvature_x_speed'] = data['curvature'] * data['speed_limit']
data['accidents_per_lane'] = data['num_reported_accidents'] / (data['num_lanes'] + 1)
data['is_high_risk_road'] = ((data['road_type'] == 2) & (data['speed_limit'] > 60)).astype(int)
data['weather_lighting_combo'] = data['weather'] * 10 + data['lighting']

# Additional feature interactions
data['speed_per_accident'] = data['speed_limit'] / (data['num_reported_accidents'] + 1)
data['risk_score'] = data['speed_limit'] * data['curvature'] / (data['num_lanes'] + 1)
data['accident_density'] = data['num_reported_accidents'] / (data['num_lanes'])
data['speed_curvature_ratio'] = data['speed_limit'] / (data['curvature'] + 1)

# Time-based features
data['time_risk'] = np.where(data['time_of_day'].isin([0, 4]), 1, 0)  # High risk times (dawn/dusk)
data['holiday_school'] = data['holiday'].astype(int) * data['school_season'].astype(int)

# Polynomial features for important numerical columns
data['speed_limit_squared'] = data['speed_limit'] ** 2
data['curvature_squared'] = data['curvature'] ** 2
data['num_lanes_squared'] = data['num_lanes'] ** 2

# Interaction between categorical and numerical features
for cat in ['road_type', 'weather', 'lighting']:
    data[f'{cat}_speed'] = data[cat] * data['speed_limit']
    data[f'{cat}_accidents'] = data[cat] * data['num_reported_accidents']
    
# Safety indicator features
data['road_complexity'] = data['curvature'] * (data['num_lanes'] / (data['road_signs_present'].astype(int) + 1))
data['weather_risk'] = data['weather'] * (data['speed_limit'] / data['num_lanes'])
data['combined_safety_score'] = (data['road_signs_present'].astype(int) * data['public_road'].astype(int)) / (data['speed_limit'] + 1)

# %%
train = data[data['source'] == 'train'].drop('source', axis=1)
test = data[data['source'] == 'test'].drop(['source', 'accident_risk'], axis=1)

X = train.drop(['accident_risk', 'id'], axis=1)
y = train['accident_risk']
X_test = test.drop('id', axis=1)

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

oof_preds_lgb = np.zeros(len(X))
oof_preds_xgb = np.zeros(len(X))
oof_preds_cat = np.zeros(len(X))
test_preds_lgb = np.zeros(len(X_test))
test_preds_xgb = np.zeros(len(X_test))
test_preds_cat = np.zeros(len(X_test))

fold = 1
for train_idx, val_idx in kf.split(X):
    print(f"\n===== Fold {fold} =====")
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    # LightGBM
    lgb_model = lgb.LGBMRegressor(
        n_estimators=3000,
        learning_rate=0.005,
        num_leaves=31,
        subsample=0.8,
        colsample_bytree=0.8,
        min_child_samples=20,
        random_state=42,
        verbose=200
    )

    early_stopping_callback = lgb.early_stopping(
    stopping_rounds=100,  # Number of rounds without improvement before stopping
    verbose=True         # Whether to print early stopping messages
    )

    lgb_model.fit(X_train, y_train, eval_set=[(X_val, y_val)], eval_metric='rmse', callbacks=[early_stopping_callback])
    lgb_pred = lgb_model.predict(X_val)
    oof_preds_lgb[val_idx] = lgb_pred
    test_preds_lgb += lgb_model.predict(X_test) / kf.n_splits

    # XGBoost
    xgb_model = xgb.XGBRegressor(
        n_estimators=3000,
        learning_rate=0.01,
        max_depth=6,
        subsample=0.8,
        colsample_bytree=0.8,
        min_child_weight=3,
        objective='reg:squarederror',
        random_state=42,
        eval_metric='rmse',
        early_stopping_rounds=100,
        verbose=200
    )
    xgb_model.fit(X_train, y_train, eval_set=[(X_val, y_val)])
    xgb_pred = xgb_model.predict(X_val)
    oof_preds_xgb[val_idx] = xgb_pred
    test_preds_xgb += xgb_model.predict(X_test) / kf.n_splits

    # CatBoost
    cat_model = CatBoostRegressor(
        iterations=3000,
        learning_rate=0.005,
        depth=6,
        l2_leaf_reg=3,
        loss_function='RMSE',
        random_seed=42,
        verbose=200
    )
    cat_model.fit(X_train, y_train, eval_set=(X_val, y_val))
    cat_pred = cat_model.predict(X_val)
    oof_preds_cat[val_idx] = cat_pred
    test_preds_cat += cat_model.predict(X_test) / kf.n_splits

    # Print individual model metrics
    fold_rmse_lgb = np.sqrt(mean_squared_error(y_val, lgb_pred))
    fold_rmse_xgb = np.sqrt(mean_squared_error(y_val, xgb_pred))
    fold_rmse_cat = np.sqrt(mean_squared_error(y_val, cat_pred))
    print(f"Fold {fold} RMSE - LGB: {fold_rmse_lgb:.5f}, XGB: {fold_rmse_xgb:.5f}, CAT: {fold_rmse_cat:.5f}")
    fold += 1

print("\nOverall OOF RMSEs:")
print("LGB:", np.sqrt(mean_squared_error(y, oof_preds_lgb)))
print("XGB:", np.sqrt(mean_squared_error(y, oof_preds_xgb)))
print("CAT:", np.sqrt(mean_squared_error(y, oof_preds_cat)))
# Out:
# ===== Fold 1 =====
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.812932
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.270068
# [LightGBM] [Debug] init for col-wise cost 0.009543 seconds, init for row-wise cost 0.049070 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013677 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 1502
# [LightGBM] [Info] Number of data points in the train set: 414203, number of used features: 35
# [LightGBM] [Info] Start training from score 0.352605
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.812932
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.270068
# [LightGBM] [Debug] init for col-wise cost 0.009543 seconds, init for row-wise cost 0.049070 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013677 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 1502
# [LightGBM] [Info] Number of data points in the train set: 414203, number of used features: 35
# [LightGBM] [Info] Start training from score 0.352605
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ...
# [2033]	validation_0-rmse:0.05597
# [2033]	validation_0-rmse:0.05597
# [2034]	validation_0-rmse:0.05597
# [2034]	validation_0-rmse:0.05597
# [2035]	validation_0-rmse:0.05597
# [2035]	validation_0-rmse:0.05597
# [2036]	validation_0-rmse:0.05597
# [2036]	validation_0-rmse:0.05597
# [2037]	validation_0-rmse:0.05597
# [2037]	validation_0-rmse:0.05597
# [2038]	validation_0-rmse:0.05597
# [2038]	validation_0-rmse:0.05597
# [2039]	validation_0-rmse:0.05597
# [2039]	validation_0-rmse:0.05597
# [2040]	validation_0-rmse:0.05597
# [2040]	validation_0-rmse:0.05597
# [2041]	validation_0-rmse:0.05596
# [2041]	validation_0-rmse:0.05596
# [2042]	validation_0-rmse:0.05596
# [2042]	validation_0-rmse:0.05596
# [2043]	validation_0-rmse:0.05597
# [2043]	validation_0-rmse:0.05597
# [2044]	validation_0-rmse:0.05596
# [2044]	validation_0-rmse:0.05596
# [2045]	validation_0-rmse:0.05596
# [2045]	validation_0-rmse:0.05596
# [2046]	validation_0-rmse:0.05596
# [2046]	validation_0-rmse:0.05596
# [2047]	validation_0-rmse:0.05596
# [2047]	validation_0-rmse:0.05596
# [2048]	validation_0-rmse:0.05596
# [2048]	validation_0-rmse:0.05596
# [2049]	validation_0-rmse:0.05596
# [2049]	validation_0-rmse:0.05596
# [2050]	validation_0-rmse:0.05596
# [2050]	validation_0-rmse:0.05596
# [2051]	validation_0-rmse:0.05596
# [2051]	validation_0-rmse:0.05596
# [2052]	validation_0-rmse:0.05596
# [2052]	validation_0-rmse:0.05596
# [2053]	validation_0-rmse:0.05596
# [2053]	validation_0-rmse:0.05596
# [2054]	validation_0-rmse:0.05596
# [2054]	validation_0-rmse:0.05596
# [2055]	validation_0-rmse:0.05596
# [2055]	validation_0-rmse:0.05596
# [2056]	validation_0-rmse:0.05596
# [2056]	validation_0-rmse:0.05596
# [2057]	validation_0-rmse:0.05596
# [2057]	validation_0-rmse:0.05596
# [2058]	validation_0-rmse:0.05596
# [2058]	validation_0-rmse:0.05596
# [2059]	validation_0-rmse:0.05596
# [2059]	validation_0-rmse:0.05596
# [2060]	validation_0-rmse:0.05596
# [2060]	validation_0-rmse:0.05596
# [2061]	validation_0-rmse:0.05596
# [2061]	validation_0-rmse:0.05596
# [2062]	validation_0-rmse:0.05596
# [2062]	validation_0-rmse:0.05596
# [2063]	validation_0-rmse:0.05596
# [2063]	validation_0-rmse:0.05596
# [2064]	validation_0-rmse:0.05596
# [2064]	validation_0-rmse:0.05596
# [2065]	validation_0-rmse:0.05596
# [2065]	validation_0-rmse:0.05596
# [2066]	validation_0-rmse:0.05596
# [2066]	validation_0-rmse:0.05596
# [2067]	validation_0-rmse:0.05596
# [2067]	validation_0-rmse:0.05596
# [2068]	validation_0-rmse:0.05596
# [2068]	validation_0-rmse:0.05596
# [2069]	validation_0-rmse:0.05596
# [2069]	validation_0-rmse:0.05596
# [2070]	validation_0-rmse:0.05596
# [2070]	validation_0-rmse:0.05596
# [2071]	validation_0-rmse:0.05596
# [2071]	validation_0-rmse:0.05596
# [2072]	validation_0-rmse:0.05596
# [2072]	validation_0-rmse:0.05596
# [2073]	validation_0-rmse:0.05596
# [2073]	validation_0-rmse:0.05596
# [2074]	validation_0-rmse:0.05596
# [2074]	validation_0-rmse:0.05596
# [2075]	validation_0-rmse:0.05596
# [2075]	validation_0-rmse:0.05596
# [2076]	validation_0-rmse:0.05596
# [2076]	validation_0-rmse:0.05596
# [2077]	validation_0-rmse:0.05596
# [2077]	validation_0-rmse:0.05596
# [2078]	validation_0-rmse:0.05596
# [2078]	validation_0-rmse:0.05596
# [2079]	validation_0-rmse:0.05596
# [2079]	validation_0-rmse:0.05596
# [2080]	validation_0-rmse:0.05596
# [2080]	validation_0-rmse:0.05596
# [2081]	validation_0-rmse:0.05596
# [2081]	validation_0-rmse:0.05596
# [2082]	validation_0-rmse:0.05596
# [2082]	validation_0-rmse:0.05596
# [2083]	validation_0-rmse:0.05596
# [2083]	validation_0-rmse:0.05596
# [2084]	validation_0-rmse:0.05596
# [2084]	validation_0-rmse:0.05596
# [2085]	validation_0-rmse:0.05596
# [2085]	validation_0-rmse:0.05596
# [2086]	validation_0-rmse:0.05596
# [2086]	validation_0-rmse:0.05596
# [2087]	validation_0-rmse:0.05596
# [2087]	validation_0-rmse:0.05596
# [2088]	validation_0-rmse:0.05596
# [2088]	validation_0-rmse:0.05596
# [2089]	validation_0-rmse:0.05596
# [2090]	validation_0-rmse:0.05596
# [2089]	validation_0-rmse:0.05596
# [2090]	validation_0-rmse:0.05596
# [2091]	validation_0-rmse:0.05596
# [2091]	validation_0-rmse:0.05596
# [2092]	validation_0-rmse:0.05596
# [2092]	validation_0-rmse:0.05596
# [2093]	validation_0-rmse:0.05596
# [2093]	validation_0-rmse:0.05596
# [2094]	validation_0-rmse:0.05596
# [2094]	validation_0-rmse:0.05596
# [2095]	validation_0-rmse:0.05596
# [2095]	validation_0-rmse:0.05596
# [2096]	validation_0-rmse:0.05596
# [2096]	validation_0-rmse:0.05596
# [2097]	validation_0-rmse:0.05596
# [2097]	validation_0-rmse:0.05596
# [2098]	validation_0-rmse:0.05596
# [2098]	validation_0-rmse:0.05596
# [2099]	validation_0-rmse:0.05596
# [2099]	validation_0-rmse:0.05596
# [2100]	validation_0-rmse:0.05596
# [2100]	validation_0-rmse:0.05596
# [2101]	validation_0-rmse:0.05596
# [2101]	validation_0-rmse:0.05596
# [2102]	validation_0-rmse:0.05596
# [2102]	validation_0-rmse:0.05596
# [2103]	validation_0-rmse:0.05596
# [2103]	validation_0-rmse:0.05596
# [2104]	validation_0-rmse:0.05596
# [2104]	validation_0-rmse:0.05596
# [2105]	validation_0-rmse:0.05596
# [2105]	validation_0-rmse:0.05596
# [2106]	validation_0-rmse:0.05596
# [2106]	validation_0-rmse:0.05596
# [2107]	validation_0-rmse:0.05596
# [2107]	validation_0-rmse:0.05596
# [2108]	validation_0-rmse:0.05596
# [2108]	validation_0-rmse:0.05596
# [2109]	validation_0-rmse:0.05596
# [2109]	validation_0-rmse:0.05596
# [2110]	validation_0-rmse:0.05596
# [2110]	validation_0-rmse:0.05596
# [2111]	validation_0-rmse:0.05596
# [2111]	validation_0-rmse:0.05596
# [2112]	validation_0-rmse:0.05596
# [2112]	validation_0-rmse:0.05596
# [2113]	validation_0-rmse:0.05596
# [2113]	validation_0-rmse:0.05596
# [2114]	validation_0-rmse:0.05596
# [2114]	validation_0-rmse:0.05596
# [2115]	validation_0-rmse:0.05596
# [2115]	validation_0-rmse:0.05596
# [2116]	validation_0-rmse:0.05596
# [2116]	validation_0-rmse:0.05596
# [2117]	validation_0-rmse:0.05596
# [2117]	validation_0-rmse:0.05596
# [2118]	validation_0-rmse:0.05596
# [2118]	validation_0-rmse:0.05596
# [2119]	validation_0-rmse:0.05596
# [2119]	validation_0-rmse:0.05596
# [2120]	validation_0-rmse:0.05596
# [2120]	validation_0-rmse:0.05596
# [2121]	validation_0-rmse:0.05596
# [2121]	validation_0-rmse:0.05596
# [2122]	validation_0-rmse:0.05596
# [2123]	validation_0-rmse:0.05596
# [2122]	validation_0-rmse:0.05596
# [2123]	validation_0-rmse:0.05596
# [2124]	validation_0-rmse:0.05596
# [2124]	validation_0-rmse:0.05596
# [2125]	validation_0-rmse:0.05596
# [2125]	validation_0-rmse:0.05596
# [2126]	validation_0-rmse:0.05596
# [2126]	validation_0-rmse:0.05596
# [2127]	validation_0-rmse:0.05596
# [2127]	validation_0-rmse:0.05596
# [2128]	validation_0-rmse:0.05596
# [2128]	validation_0-rmse:0.05596
# [2129]	validation_0-rmse:0.05596
# [2129]	validation_0-rmse:0.05596
# [2130]	validation_0-rmse:0.05596
# [2130]	validation_0-rmse:0.05596
# [2131]	validation_0-rmse:0.05596
# [2131]	validation_0-rmse:0.05596
# [2132]	validation_0-rmse:0.05596
# [2132]	validation_0-rmse:0.05596
# [2133]	validation_0-rmse:0.05596
# [2133]	validation_0-rmse:0.05596
# [2134]	validation_0-rmse:0.05596
# [2134]	validation_0-rmse:0.05596
# [2135]	validation_0-rmse:0.05596
# [2135]	validation_0-rmse:0.05596
# [2136]	validation_0-rmse:0.05596
# [2136]	validation_0-rmse:0.05596
# [2137]	validation_0-rmse:0.05596
# [2137]	validation_0-rmse:0.05596
# [2138]	validation_0-rmse:0.05596
# [2138]	validation_0-rmse:0.05596
# [2139]	validation_0-rmse:0.05596
# [2139]	validation_0-rmse:0.05596
# [2140]	validation_0-rmse:0.05596
# [2140]	validation_0-rmse:0.05596
# [2141]	validation_0-rmse:0.05596
# [2141]	validation_0-rmse:0.05596
# [2142]	validation_0-rmse:0.05596
# [2142]	validation_0-rmse:0.05596
# [2143]	validation_0-rmse:0.05596
# [2143]	validation_0-rmse:0.05596
# [2144]	validation_0-rmse:0.05596
# [2144]	validation_0-rmse:0.05596
# [2145]	validation_0-rmse:0.05596
# [2145]	validation_0-rmse:0.05596
# [2146]	validation_0-rmse:0.05596
# [2146]	validation_0-rmse:0.05596
# [2147]	validation_0-rmse:0.05596
# [2147]	validation_0-rmse:0.05596
# [2148]	validation_0-rmse:0.05596
# [2148]	validation_0-rmse:0.05596
# [2149]	validation_0-rmse:0.05596
# [2149]	validation_0-rmse:0.05596
# [2150]	validation_0-rmse:0.05596
# [2150]	validation_0-rmse:0.05596
# [2151]	validation_0-rmse:0.05596
# [2151]	validation_0-rmse:0.05596
# [2152]	validation_0-rmse:0.05596
# [2152]	validation_0-rmse:0.05596
# [2153]	validation_0-rmse:0.05596
# [2153]	validation_0-rmse:0.05596
# [2154]	validation_0-rmse:0.05596
# [2154]	validation_0-rmse:0.05596
# [2155]	validation_0-rmse:0.05596
# [2155]	validation_0-rmse:0.05596
# [2156]	validation_0-rmse:0.05596
# [2156]	validation_0-rmse:0.05596
# [2157]	validation_0-rmse:0.05596
# [2157]	validation_0-rmse:0.05596
# [2158]	validation_0-rmse:0.05596
# [2158]	validation_0-rmse:0.05596
# [2159]	validation_0-rmse:0.05596
# [2159]	validation_0-rmse:0.05596
# [2160]	validation_0-rmse:0.05596
# [2161]	validation_0-rmse:0.05596
# [2160]	validation_0-rmse:0.05596
# [2161]	validation_0-rmse:0.05596
# [2162]	validation_0-rmse:0.05596
# [2162]	validation_0-rmse:0.05596
# [2163]	validation_0-rmse:0.05596
# [2163]	validation_0-rmse:0.05596
# [2164]	validation_0-rmse:0.05596
# [2164]	validation_0-rmse:0.05596
# [2165]	validation_0-rmse:0.05596
# [2165]	validation_0-rmse:0.05596
# [2166]	validation_0-rmse:0.05596
# [2166]	validation_0-rmse:0.05596
# [2167]	validation_0-rmse:0.05596
# [2167]	validation_0-rmse:0.05596
# [2168]	validation_0-rmse:0.05596
# [2168]	validation_0-rmse:0.05596
# [2169]	validation_0-rmse:0.05596
# [2169]	validation_0-rmse:0.05596
# [2170]	validation_0-rmse:0.05596
# [2170]	validation_0-rmse:0.05596
# [2171]	validation_0-rmse:0.05596
# [2171]	validation_0-rmse:0.05596
# [2172]	validation_0-rmse:0.05596
# [2172]	validation_0-rmse:0.05596
# [2173]	validation_0-rmse:0.05596
# [2173]	validation_0-rmse:0.05596
# [2174]	validation_0-rmse:0.05596
# [2174]	validation_0-rmse:0.05596
# [2175]	validation_0-rmse:0.05596
# [2175]	validation_0-rmse:0.05596
# [2176]	validation_0-rmse:0.05596
# [2176]	validation_0-rmse:0.05596
# [2177]	validation_0-rmse:0.05596
# [2177]	validation_0-rmse:0.05596
# [2178]	validation_0-rmse:0.05596
# [2178]	validation_0-rmse:0.05596
# [2179]	validation_0-rmse:0.05596
# [2179]	validation_0-rmse:0.05596
# [2180]	validation_0-rmse:0.05596
# [2180]	validation_0-rmse:0.05596
# [2181]	validation_0-rmse:0.05596
# [2181]	validation_0-rmse:0.05596
# [2182]	validation_0-rmse:0.05596
# [2182]	validation_0-rmse:0.05596
# [2183]	validation_0-rmse:0.05596
# [2183]	validation_0-rmse:0.05596
# [2184]	validation_0-rmse:0.05596
# [2184]	validation_0-rmse:0.05596
# [2185]	validation_0-rmse:0.05596
# [2185]	validation_0-rmse:0.05596
# [2186]	validation_0-rmse:0.05596
# [2186]	validation_0-rmse:0.05596
# [2187]	validation_0-rmse:0.05596
# [2187]	validation_0-rmse:0.05596
# [2188]	validation_0-rmse:0.05596
# [2188]	validation_0-rmse:0.05596
# [2189]	validation_0-rmse:0.05596
# [2189]	validation_0-rmse:0.05596
# [2190]	validation_0-rmse:0.05596
# [2190]	validation_0-rmse:0.05596
# [2191]	validation_0-rmse:0.05596
# [2191]	validation_0-rmse:0.05596
# [2192]	validation_0-rmse:0.05596
# [2192]	validation_0-rmse:0.05596
# [2193]	validation_0-rmse:0.05596
# [2193]	validation_0-rmse:0.05596
# [2194]	validation_0-rmse:0.05596
# [2194]	validation_0-rmse:0.05596
# [2195]	validation_0-rmse:0.05596
# [2195]	validation_0-rmse:0.05596
# [2196]	validation_0-rmse:0.05596
# [2196]	validation_0-rmse:0.05596
# [2197]	validation_0-rmse:0.05596
# [2197]	validation_0-rmse:0.05596
# [2198]	validation_0-rmse:0.05596
# [2198]	validation_0-rmse:0.05596
# [2199]	validation_0-rmse:0.05596
# [2199]	validation_0-rmse:0.05596
# [2200]	validation_0-rmse:0.05596
# [2200]	validation_0-rmse:0.05596
# [2201]	validation_0-rmse:0.05596
# [2201]	validation_0-rmse:0.05596
# [2202]	validation_0-rmse:0.05596
# [2202]	validation_0-rmse:0.05596
# [2203]	validation_0-rmse:0.05596
# [2203]	validation_0-rmse:0.05596
# [2204]	validation_0-rmse:0.05596
# [2204]	validation_0-rmse:0.05596
# [2205]	validation_0-rmse:0.05596
# [2205]	validation_0-rmse:0.05596
# [2206]	validation_0-rmse:0.05596
# [2206]	validation_0-rmse:0.05596
# [2207]	validation_0-rmse:0.05596
# [2207]	validation_0-rmse:0.05596
# [2208]	validation_0-rmse:0.05596
# [2208]	validation_0-rmse:0.05596
# [2209]	validation_0-rmse:0.05596
# [2209]	validation_0-rmse:0.05596
# [2210]	validation_0-rmse:0.05596
# [2210]	validation_0-rmse:0.05596
# [2211]	validation_0-rmse:0.05596
# [2211]	validation_0-rmse:0.05596
# [2212]	validation_0-rmse:0.05596
# [2212]	validation_0-rmse:0.05596
# [2213]	validation_0-rmse:0.05596
# [2213]	validation_0-rmse:0.05596
# [2214]	validation_0-rmse:0.05596
# [2214]	validation_0-rmse:0.05596
# [2215]	validation_0-rmse:0.05596
# [2215]	validation_0-rmse:0.05596
# [2216]	validation_0-rmse:0.05596
# [2216]	validation_0-rmse:0.05596
# [2217]	validation_0-rmse:0.05596
# [2217]	validation_0-rmse:0.05596
# [2218]	validation_0-rmse:0.05596
# [2218]	validation_0-rmse:0.05596
# [2219]	validation_0-rmse:0.05596
# [2219]	validation_0-rmse:0.05596
# [2220]	validation_0-rmse:0.05596
# [2220]	validation_0-rmse:0.05596
# [2221]	validation_0-rmse:0.05596
# [2221]	validation_0-rmse:0.05596
# [2222]	validation_0-rmse:0.05596
# [2222]	validation_0-rmse:0.05596
# [2223]	validation_0-rmse:0.05596
# [2223]	validation_0-rmse:0.05596
# [2224]	validation_0-rmse:0.05596
# [2224]	validation_0-rmse:0.05596
# 0:	learn: 0.1656858	test: 0.1658574	best: 0.1658574 (0)	total: 36.2ms	remaining: 1m 48s
# 0:	learn: 0.1656858	test: 0.1658574	best: 0.1658574 (0)	total: 36.2ms	remaining: 1m 48s
# 200:	learn: 0.0847555	test: 0.0847513	best: 0.0847513 (200)	total: 7.04s	remaining: 1m 38s
# 200:	learn: 0.0847555	test: 0.0847513	best: 0.0847513 (200)	total: 7.04s	remaining: 1m 38s
# 400:	learn: 0.0630310	test: 0.0629807	best: 0.0629807 (400)	total: 13.8s	remaining: 1m 29s
# 400:	learn: 0.0630310	test: 0.0629807	best: 0.0629807 (400)	total: 13.8s	remaining: 1m 29s
# 600:	learn: 0.0582365	test: 0.0581766	best: 0.0581766 (600)	total: 20.3s	remaining: 1m 21s
# 600:	learn: 0.0582365	test: 0.0581766	best: 0.0581766 (600)	total: 20.3s	remaining: 1m 21s
# 800:	learn: 0.0571220	test: 0.0570552	best: 0.0570552 (800)	total: 26.9s	remaining: 1m 13s
# 800:	learn: 0.0571220	test: 0.0570552	best: 0.0570552 (800)	total: 26.9s	remaining: 1m 13s
# 1000:	learn: 0.0568080	test: 0.0567380	best: 0.0567380 (1000)	total: 33.3s	remaining: 1m 6s
# 1000:	learn: 0.0568080	test: 0.0567380	best: 0.0567380 (1000)	total: 33.3s	remaining: 1m 6s
# 1200:	learn: 0.0566762	test: 0.0566039	best: 0.0566039 (1200)	total: 39.6s	remaining: 59.3s
# 1200:	learn: 0.0566762	test: 0.0566039	best: 0.0566039 (1200)	total: 39.6s	remaining: 59.3s
# 1400:	learn: 0.0566008	test: 0.0565290	best: 0.0565290 (1400)	total: 45.9s	remaining: 52.4s
# 1400:	learn: 0.0566008	test: 0.0565290	best: 0.0565290 (1400)	total: 45.9s	remaining: 52.4s
# 1600:	learn: 0.0565432	test: 0.0564749	best: 0.0564749 (1600)	total: 52.2s	remaining: 45.6s
# 1600:	learn: 0.0565432	test: 0.0564749	best: 0.0564749 (1600)	total: 52.2s	remaining: 45.6s
# 1800:	learn: 0.0564958	test: 0.0564314	best: 0.0564314 (1800)	total: 58.7s	remaining: 39.1s
# 1800:	learn: 0.0564958	test: 0.0564314	best: 0.0564314 (1800)	total: 58.7s	remaining: 39.1s
# 2000:	learn: 0.0564555	test: 0.0563957	best: 0.0563957 (2000)	total: 1m 4s	remaining: 32.2s
# 2000:	learn: 0.0564555	test: 0.0563957	best: 0.0563957 (2000)	total: 1m 4s	remaining: 32.2s
# 2200:	learn: 0.0564190	test: 0.0563641	best: 0.0563641 (2200)	total: 1m 9s	remaining: 25.2s
# 2200:	learn: 0.0564190	test: 0.0563641	best: 0.0563641 (2200)	total: 1m 9s	remaining: 25.2s
# 2400:	learn: 0.0563862	test: 0.0563372	best: 0.0563372 (2400)	total: 1m 14s	remaining: 18.5s
# 2400:	learn: 0.0563862	test: 0.0563372	best: 0.0563372 (2400)	total: 1m 14s	remaining: 18.5s
# 2600:	learn: 0.0563541	test: 0.0563112	best: 0.0563112 (2600)	total: 1m 19s	remaining: 12.2s
# 2600:	learn: 0.0563541	test: 0.0563112	best: 0.0563112 (2600)	total: 1m 19s	remaining: 12.2s
# 2800:	learn: 0.0563247	test: 0.0562874	best: 0.0562874 (2800)	total: 1m 24s	remaining: 5.99s
# 2800:	learn: 0.0563247	test: 0.0562874	best: 0.0562874 (2800)	total: 1m 24s	remaining: 5.99s
# 2999:	learn: 0.0562971	test: 0.0562653	best: 0.0562653 (2999)	total: 1m 29s	remaining: 0us
#
# bestTest = 0.0562653116
# bestIteration = 2999
#
# Fold 5 RMSE - LGB: 0.05610, XGB: 0.05596, CAT: 0.05627
#
# Overall OOF RMSEs:
# LGB: 0.0562102528115296
# XGB: 0.05609943124825606
# CAT: 0.05637887515857139
# 2999:	learn: 0.0562971	test: 0.0562653	best: 0.0562653 (2999)	total: 1m 29s	remaining: 0us
#
# bestTest = 0.0562653116
# bestIteration = 2999
#
# Fold 5 RMSE - LGB: 0.05610, XGB: 0.05596, CAT: 0.05627
#
# Overall OOF RMSEs:
# LGB: 0.0562102528115296
# XGB: 0.05609943124825606
# CAT: 0.05637887515857139

# %%
# Create stacking features using OOF predictions
stack_train = np.vstack([oof_preds_lgb, oof_preds_xgb, oof_preds_cat]).T
stack_test = np.vstack([test_preds_lgb, test_preds_xgb, test_preds_cat]).T

# Add weighted version of predictions to the stacking features
weights = np.array([0.4, 0.3, 0.3])  # Initial weights based on typical performance
weighted_oof = (oof_preds_lgb * weights[0] + oof_preds_xgb * weights[1] + oof_preds_cat * weights[2])
weighted_test = (test_preds_lgb * weights[0] + test_preds_xgb * weights[1] + test_preds_cat * weights[2])

stack_train = np.hstack([stack_train, weighted_oof.reshape(-1, 1)])
stack_test = np.hstack([stack_test, weighted_test.reshape(-1, 1)])

# Fit meta model with regularization
meta = Ridge(alpha=0.5)
meta.fit(stack_train, y)
final_test_pred = meta.predict(stack_test)
final_test_pred = np.clip(final_test_pred, 0, 1)

print("Meta ensemble complete.")
print("Meta model coefficients:", meta.coef_)
# Out:
# Meta ensemble complete.
# Meta model coefficients: [ 0.07499567  0.7820162  -0.09322291  0.23663625]

# %%
submission = pd.DataFrame({
    'id': test['id'],
    'accident_risk': final_test_pred
})

submission.to_csv("submission.csv", index=False)
submission.head()
# Out:
#             id  accident_risk
# 517754  517754       0.291179
# 517755  517755       0.123618
# 517756  517756       0.182553
# 517757  517757       0.318115
# 517758  517758       0.392975
